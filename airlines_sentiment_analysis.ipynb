# %%
import pandas as pd
tweets= pd.read_csv ('C:/Users/Ajit/Desktop/Web_mining_yegin/Airline-Tweets.csv', encoding="latin-1")

# %%
tweets.head
# Out:
#         _unit_id         airline             name  retweet_count  \
# 0      681448150  Virgin America          cairdin              0
# 1      681448153  Virgin America         jnardino              0
# 2      681448156  Virgin America       yvonnalynn              0
# 3      681448158  Virgin America         jnardino              0
# 4      681448159  Virgin America         jnardino              0
# ...          ...             ...              ...            ...
# 14635  681679794        American  KristenReenders              0
# 14636  681679795        American         itsropes              0
# 14637  681679796        American         sanyabun              0
# 14638  681679797        American       SraJackson              0
# 14639  681679798        American        daviddtwu              0
#
#                                                     text  tweet_created  \
# 0                    @VirginAmerica What @dhepburn said.  2/24/15 11:35
# ...
